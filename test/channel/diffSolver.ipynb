# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
U_myrhopimple= np.loadtxt("myrhopimplefoam.csv",skiprows=1,usecols=0,delimiter=",",unpack=True)
U_rhopimple= np.loadtxt("rhopimplefoam.csv",skiprows=1,usecols=0,delimiter=",",unpack=True)

# %%
diff= np.abs(U_myrhopimple-U_rhopimple)

# %%
diff
# Out:
# array([2.16148124e-04, 2.13721971e-04, 2.11591992e-04, ...,
#        9.31320000e-10, 9.31320000e-10, 9.31320000e-10])

# %%
plt.plot(diff)
plt.yscale("log")
